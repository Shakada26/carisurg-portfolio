# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakada26/carisurg-portfolio/blob/main/day1_gender_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("EmergencyTriageDataset_Reduced_Dirty.csv")

# Check Gender values before cleaning
print("Before Cleaning:")
print(df["Gender"].unique())

# Clean Gender column
df["Gender"] = df["Gender"].astype(str).str.strip().str.upper()

# Standardize values
df["Gender"] = df["Gender"].replace({
    "M": "Male",
    "MALE": "Male",
    "F": "Female",
    "FEMALE": "Female"
})

# Check Gender values after cleaning
print("\nAfter Cleaning:")
print(df["Gender"].unique())
# Out:
# Before Cleaning:
# ['0' 'Male' 'Female' 'FEMALE' '1' 'MALE']
#
# After Cleaning:
# ['0' 'Male' 'Female' '1']

# %%
import pandas as pd

df = pd.read_csv('/content/EmergencyTriageDataset_Reduced_Dirty.csv')
print(df.head())
